# %% [markdown]
# # Monte Carlo Tree Search (MCTS) with UCT
# This notebook introduces the core ideas behind Monte Carlo Tree Search (MCTS)
# using a minimal working example based on UCT (Upper Confidence Bound applied to Trees).
#
# You will implement:
# - UCT-based **Selection**
# - Node **Expansion**
# - **Rollout** simulation
# - **Backpropagation** of returns
# - Tracking visit counts and Q-values
# - Updating action preferences at the root node
#
# We will follow the four classical MCTS phases.

# %%
import math
import random

# Good research should be reproducible - lets get a random seed
random.seed(42)

# %%
# Consider the following initial problem situation
Q = {("s0", "a1"): 0.55,
     ("s0", "a2"): 0.40}

N = {"s0": 20}   #Total number of visits for the state
Nsa = {("s0", "a1"): 12,
       ("s0", "a2"): 8}  # visit counts per action in the state

c = math.sqrt(2)   # some exploration constant

# %%
def uct(s, a):
    """Will help compute the UCT score for action a in state s."""
    return Q[(s, a)] + c * math.sqrt(math.log(N[s]) / Nsa[(s, a)])

# %% [markdown]
# ### Task 1:
# write code to print the UCT score for both a1 and a2 at s0. Further, print which action, UCT  selects

# %%
"Your code goes here"
uct_a1 = uct("s0", "a1")
uct_a2 = uct("s0", "a2")

print(f"UCT(s0, a1) = {uct_a1:.4f}")
print(f"UCT(s0, a2) = {uct_a2:.4f}")

selected_action = max(["a1", "a2"], key=lambda a: uct("s0", a))
print(f"UCT selects action: {selected_action}")
# Out:
# UCT(s0, a1) = 1.2566
# UCT(s0, a2) = 1.2654
# UCT selects action: a2

# %% [markdown]
# As discussed in class, each iteration of MCTS consists of four key phases:
#
#  * Selection: Starting at the root, select child nodes  until a leaf is reached using a balance between exploration and exploitation.
#  * Expansion: Add one or more new child nodes (previously unvisited states).
#  * Rollout Perform a random or heuristic-guided simulation from the new node to a terminal state to estimate its value.
# * Backpropagation Update value estimates and visit counts along the path back to the root.

# %%
def run_iteration(iteration_num=None):
    #Run one iteration of MCTS with detailed logging.

    if iteration_num is not None:
        print(f"\n{'=' * 60}")
        print(f"ITERATION {iteration_num}")
        print(f"{'=' * 60}")

    # (1) --- Selection ---
    if iteration_num is not None:
        print("\n(1) SELECTION:")
        print(f"  Current Q-values: Q(s0,a1)={Q[('s0','a1')]:.4f}, Q(s0,a2)={Q[('s0','a2')]:.4f}")
        print(f"  Current visit counts: N(s0,a1)={Nsa[('s0','a1')]}, N(s0,a2)={Nsa[('s0','a2')]}")
        print(f"  UCT(s0,a1)={uct('s0','a1'):.4f}, UCT(s0,a2)={uct('s0','a2'):.4f}")

    a = max(["a1", "a2"], key=lambda x: uct("s0", x))

    if iteration_num is not None:
        print(f"  Selected action: {a}")

    # (2) --- Expansion ---
    if iteration_num is not None:
        print("\n(2) EXPANSION:")
        print(f"  Expanding from s0 via action {a} to create new child state s_new")

    s_new = "s_new"

    # (3) --- Rollout ---
    R = random.random()  # Return from simulation

    if iteration_num is not None:
        print("\n(3) ROLLOUT:")
        print(f"  Simulating from s_new to terminal state")
        print(f"  Return received: R = {R:.4f}")

    # (4) --- Backpropagation ---
    if iteration_num is not None:
        print("\n(4) BACKPROPAGATION:")
        print(f"  Before update: N(s0)={N['s0']}, N(s0,{a})={Nsa[('s0',a)]}, Q(s0,{a})={Q[('s0',a)]:.4f}")

    N["s0"] += 1
    Nsa[("s0", a)] += 1

    # Incremental mean update:
    Q[(s0 := "s0", a)] += (R - Q[(s0, a)]) / Nsa[(s0, a)]

    if iteration_num is not None:
        print(f"  After update:  N(s0)={N['s0']}, N(s0,{a})={Nsa[('s0',a)]}, Q(s0,{a})={Q[('s0',a)]:.4f}")

    return a, R

# %% [markdown]
# **Task 2:**
# Write code to run simulations, before running each iteration document what changes during:
# - Selection
# - Expansion
# - Rollout
# - Backpropagation

# %%
"Your code goes here"
num_iterations = 20

for i in range(1, num_iterations + 1):
    action, reward = run_iteration(i)
# Out:
# ============================================================
# ITERATION 1
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5500, Q(s0,a2)=0.4000
#   Current visit counts: N(s0,a1)=12, N(s0,a2)=8
#   UCT(s0,a1)=1.2566, UCT(s0,a2)=1.2654
#   Selected action: a2
#
# (2) EXPANSION:
#   Expanding from s0 via action a2 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.2449
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=20, N(s0,a2)=8, Q(s0,a2)=0.4000
#   After update:  N(s0)=21, N(s0,a2)=9, Q(s0,a2)=0.3828
#
# ============================================================
# ITERATION 2
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5500, Q(s0,a2)=0.3828
#   Current visit counts: N(s0,a1)=12, N(s0,a2)=9
#   UCT(s0,a1)=1.2623, UCT(s0,a2)=1.2053
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.1395
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=21, N(s0,a1)=12, Q(s0,a1)=0.5500
#   After update:  N(s0)=22, N(s0,a1)=13, Q(s0,a1)=0.5184
#
# ============================================================
# ITERATION 3
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5184, Q(s0,a2)=0.3828
#   Current visit counts: N(s0,a1)=13, N(s0,a2)=9
#   UCT(s0,a1)=1.2080, UCT(s0,a2)=1.2116
#   Selected action: a2
#
# (2) EXPANSION:
#   Expanding from s0 via action a2 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.1025
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=22, N(s0,a2)=9, Q(s0,a2)=0.3828
#   After update:  N(s0)=23, N(s0,a2)=10, Q(s0,a2)=0.3547
#
# ============================================================
# ITERATION 4
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5184, Q(s0,a2)=0.3547
#   Current visit counts: N(s0,a1)=13, N(s0,a2)=10
#   UCT(s0,a1)=1.2130, UCT(s0,a2)=1.1466
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.7407
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=23, N(s0,a1)=13, Q(s0,a1)=0.5184
#   After update:  N(s0)=24, N(s0,a1)=14, Q(s0,a1)=0.5343
#
# ============================================================
# ITERATION 5
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5343, Q(s0,a2)=0.3547
#   Current visit counts: N(s0,a1)=14, N(s0,a2)=10
#   UCT(s0,a1)=1.2081, UCT(s0,a2)=1.1520
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.5454
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=24, N(s0,a1)=14, Q(s0,a1)=0.5343
#   After update:  N(s0)=25, N(s0,a1)=15, Q(s0,a1)=0.5350
#
# ============================================================
# ITERATION 6
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5350, Q(s0,a2)=0.3547
#   Current visit counts: N(s0,a1)=15, N(s0,a2)=10
#   UCT(s0,a1)=1.1902, UCT(s0,a2)=1.1571
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.5905
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=25, N(s0,a1)=15, Q(s0,a1)=0.5350
#   After update:  N(s0)=26, N(s0,a1)=16, Q(s0,a1)=0.5385
#
# ============================================================
# ITERATION 7
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5385, Q(s0,a2)=0.3547
#   Current visit counts: N(s0,a1)=16, N(s0,a2)=10
#   UCT(s0,a1)=1.1767, UCT(s0,a2)=1.1620
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.0318
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=26, N(s0,a1)=16, Q(s0,a1)=0.5385
#   After update:  N(s0)=27, N(s0,a1)=17, Q(s0,a1)=0.5087
#
# ============================================================
# ITERATION 8
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5087, Q(s0,a2)=0.3547
#   Current visit counts: N(s0,a1)=17, N(s0,a2)=10
#   UCT(s0,a1)=1.1314, UCT(s0,a2)=1.1666
#   Selected action: a2
#
# (2) EXPANSION:
#   Expanding from s0 via action a2 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.0937
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=27, N(s0,a2)=10, Q(s0,a2)=0.3547
#   After update:  N(s0)=28, N(s0,a2)=11, Q(s0,a2)=0.3310
#
# ============================================================
# ITERATION 9
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5087, Q(s0,a2)=0.3310
#   Current visit counts: N(s0,a1)=17, N(s0,a2)=11
#   UCT(s0,a1)=1.1348, UCT(s0,a2)=1.1094
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.2327
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=28, N(s0,a1)=17, Q(s0,a1)=0.5087
#   After update:  N(s0)=29, N(s0,a1)=18, Q(s0,a1)=0.4934
#
# ============================================================
# ITERATION 10
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.4934, Q(s0,a2)=0.3310
#   Current visit counts: N(s0,a1)=18, N(s0,a2)=11
#   UCT(s0,a1)=1.1050, UCT(s0,a2)=1.1135
#   Selected action: a2
#
# (2) EXPANSION:
#   Expanding from s0 via action a2 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.6020
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=29, N(s0,a2)=11, Q(s0,a2)=0.3310
#   After update:  N(s0)=30, N(s0,a2)=12, Q(s0,a2)=0.3536
#
# ============================================================
# ITERATION 11
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.4934, Q(s0,a2)=0.3536
#   Current visit counts: N(s0,a1)=18, N(s0,a2)=12
#   UCT(s0,a1)=1.1081, UCT(s0,a2)=1.1065
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.5612
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=30, N(s0,a1)=18, Q(s0,a1)=0.4934
#   After update:  N(s0)=31, N(s0,a1)=19, Q(s0,a1)=0.4969
#
# ============================================================
# ITERATION 12
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.4969, Q(s0,a2)=0.3536
#   Current visit counts: N(s0,a1)=19, N(s0,a2)=12
#   UCT(s0,a1)=1.0982, UCT(s0,a2)=1.1101
#   Selected action: a2
#
# (2) EXPANSION:
#   Expanding from s0 via action a2 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.7160
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=31, N(s0,a2)=12, Q(s0,a2)=0.3536
#   After update:  N(s0)=32, N(s0,a2)=13, Q(s0,a2)=0.3815
#
# ============================================================
# ITERATION 13
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.4969, Q(s0,a2)=0.3815
#   Current visit counts: N(s0,a1)=19, N(s0,a2)=13
#   UCT(s0,a1)=1.1009, UCT(s0,a2)=1.1117
#   Selected action: a2
#
# (2) EXPANSION:
#   Expanding from s0 via action a2 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.7013
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=32, N(s0,a2)=13, Q(s0,a2)=0.3815
#   After update:  N(s0)=33, N(s0,a2)=14, Q(s0,a2)=0.4043
#
# ============================================================
# ITERATION 14
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.4969, Q(s0,a2)=0.4043
#   Current visit counts: N(s0,a1)=19, N(s0,a2)=14
#   UCT(s0,a1)=1.1036, UCT(s0,a2)=1.1111
#   Selected action: a2
#
# (2) EXPANSION:
#   Expanding from s0 via action a2 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.4195
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=33, N(s0,a2)=14, Q(s0,a2)=0.4043
#   After update:  N(s0)=34, N(s0,a2)=15, Q(s0,a2)=0.4053
#
# ============================================================
# ITERATION 15
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.4969, Q(s0,a2)=0.4053
#   Current visit counts: N(s0,a1)=19, N(s0,a2)=15
#   UCT(s0,a1)=1.1062, UCT(s0,a2)=1.0910
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.4492
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=34, N(s0,a1)=19, Q(s0,a1)=0.4969
#   After update:  N(s0)=35, N(s0,a1)=20, Q(s0,a1)=0.4945
#
# ============================================================
# ITERATION 16
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.4945, Q(s0,a2)=0.4053
#   Current visit counts: N(s0,a1)=20, N(s0,a2)=15
#   UCT(s0,a1)=1.0908, UCT(s0,a2)=1.0938
#   Selected action: a2
#
# (2) EXPANSION:
#   Expanding from s0 via action a2 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.2782
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=35, N(s0,a2)=15, Q(s0,a2)=0.4053
#   After update:  N(s0)=36, N(s0,a2)=16, Q(s0,a2)=0.3974
#
# ============================================================
# ITERATION 17
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.4945, Q(s0,a2)=0.3974
#   Current visit counts: N(s0,a1)=20, N(s0,a2)=16
#   UCT(s0,a1)=1.0932, UCT(s0,a2)=1.0667
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.8693
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=36, N(s0,a1)=20, Q(s0,a1)=0.4945
#   After update:  N(s0)=37, N(s0,a1)=21, Q(s0,a1)=0.5124
#
# ============================================================
# ITERATION 18
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5124, Q(s0,a2)=0.3974
#   Current visit counts: N(s0,a1)=21, N(s0,a2)=16
#   UCT(s0,a1)=1.0988, UCT(s0,a2)=1.0692
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.7588
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=37, N(s0,a1)=21, Q(s0,a1)=0.5124
#   After update:  N(s0)=38, N(s0,a1)=22, Q(s0,a1)=0.5236
#
# ============================================================
# ITERATION 19
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5236, Q(s0,a2)=0.3974
#   Current visit counts: N(s0,a1)=22, N(s0,a2)=16
#   UCT(s0,a1)=1.0987, UCT(s0,a2)=1.0717
#   Selected action: a1
#
# (2) EXPANSION:
#   Expanding from s0 via action a1 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.1597
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=38, N(s0,a1)=22, Q(s0,a1)=0.5236
#   After update:  N(s0)=39, N(s0,a1)=23, Q(s0,a1)=0.5078
#
# ============================================================
# ITERATION 20
# ============================================================
#
# (1) SELECTION:
#   Current Q-values: Q(s0,a1)=0.5078, Q(s0,a2)=0.3974
#   Current visit counts: N(s0,a1)=23, N(s0,a2)=16
#   UCT(s0,a1)=1.0722, UCT(s0,a2)=1.0741
#   Selected action: a2
#
# (2) EXPANSION:
#   Expanding from s0 via action a2 to create new child state s_new
#
# (3) ROLLOUT:
#   Simulating from s_new to terminal state
#   Return received: R = 0.4226
#
# (4) BACKPROPAGATION:
#   Before update: N(s0)=39, N(s0,a2)=16, Q(s0,a2)=0.3974
#   After update:  N(s0)=40, N(s0,a2)=17, Q(s0,a2)=0.3989

# %% [markdown]
# ### Task 3:
#
# Write code that will print:
# Final Q values,
#
# *   Final Q values
# *   Final Visit Counts
# *   Preferred at root, s0

# %%
"Your code goes here"
print("Final Q values:")
print(f"Q(s0, a1) = {Q[('s0', 'a1')]:.4f}")
print(f"Q(s0, a2) = {Q[('s0', 'a2')]:.4f}")

print("\nFinal visit counts:")
print(f"N(s0) = {N['s0']}")
print(f"N(s0, a1) = {Nsa[('s0', 'a1')]}")
print(f"N(s0, a2) = {Nsa[('s0', 'a2')]}")

preferred_action = max(["a1", "a2"], key=lambda a: Q[("s0", a)])

print(f"\nPreferred action at root s0: {preferred_action}")
# Out:
# Final Q values:
# Q(s0, a1) = 0.5078
# Q(s0, a2) = 0.3989
#
# Final visit counts:
# N(s0) = 40
# N(s0, a1) = 23
# N(s0, a2) = 17
#
# Preferred action at root s0: a1

# %% [markdown]
# ### Task 4:
# Interpret the results:
# 1. Which action does MCTS end up preferring?
# 2. Why did the preferred action change or stay the same over the 20 iterations?
# 3. How does UCT balance exploration and exploitation in your observed results?

# %%
1.After 20 iterations, MCTS ends up preferring action a1 at the root state s0 because Q(s0, a1) is higher than Q(s0, a2)

# %%
2. At the beginning, UCT selected a2. This was because a2 had been visited fewer times. According to the  UCT formula, Q(s0, a2) 
received a higher exploration bonus. However, as more rollouts were performed, the Q-values were updated using the sampled returns. 
Over time, a1 became the better estimated action, so after 20 iterations, the final preferred action became a1.

# %%
3. UCT balances exploration and exploitation by combining two terms. The Q-value term encourages the algorithm to 
choose actions that currently look good. The exploration bonus encourages the algorithm to try actions that have 
been visited fewer times. 

MCTS does not always choose the action with the highest Q-value at the start. 
Instead, it sometimes selects a less-visited action to gather more information.

# %% [markdown]
# ## Optional Challenge:
# Extend this notebook by implementing:
#
# 1. A real tree structure with:
#    - multiple layers,
#    - children stored in a dictionary: `children[s] = [list_of_actions]`.
#
# 2. A real rollout policy (random or epsilon-greedy).
#
# 3. Backpropagation that updates *all* ancestors, not only s0.
#
# 4. Visualization of visit counts as a bar chart.
